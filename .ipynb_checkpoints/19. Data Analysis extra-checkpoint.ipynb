# %% [markdown]
# # Analysis with multiple columns

# %%
import numpy as np
import pandas as pd

from sklearn.impute import SimpleImputer

# %%
df = pd.read_csv('Datasets/googleplaystore.csv')

impute = SimpleImputer(missing_values = np.nan , strategy = 'mean')
impute.fit(df.iloc[ : , 2:3 ].values)
df.iloc[ : , 2:3 ] = impute.transform(df.iloc[ : , 2:3 ].values)

df = df.dropna()

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# 1  Art & Design;Pretend Play  January 15, 2018               2.0.0
# 2               Art & Design    August 1, 2018               1.2.4
# 3               Art & Design      June 8, 2018  Varies with device
# 4    Art & Design;Creativity     June 20, 2018                 1.1
#
#     Android Ver
# 0  4.0.3 and up
# 1  4.0.3 and up
# 2  4.0.3 and up
# 3    4.2 and up
# 4    4.4 and up

# %%
df.isnull().sum()
# Out:
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size              0
# Installs          0
# Type              0
# Price             0
# Content Rating    0
# Genres            0
# Last Updated      0
# Current Ver       0
# Android Ver       0
# dtype: int64

# %% [markdown]
# ## Q1. How many free apps are there in ART_AND_DESIGN?

# %%
df1 = df.values # converts into numpyarray

# %%
# main code to solve question. 
c = 0

for i in df1:
    if(i[1] == 'ART_AND_DESIGN' and i[6] == 'Free'): #choose column
        c += 1
        
print("There are",c,'free apps from ART_AND_DESIGN')
# Out:
# There are 61 free apps from ART_AND_DESIGN

# %% [markdown]
# ## Q2. How many apps are there in ART_AND_DESIGN with rating more then 4.5?

# %%
c = 0
for i in df1:
    if(i[1] == 'ART_AND_DESIGN' and i[2] > 4.5): #choose column
        c += 1
print(c)
# Out:
# 22

# %% [markdown]
# ## Q3. How many apps are there in FAMILY with rating more then 4.5 and Free?

# %%
c = 0
for i in df1:
    if(i[1] == 'ART_AND_DESIGN' and i[2] > 4.5 and i[6]== 'Free'): #choose column
        c += 1
print(c)
# Out:
# 19

# %% [markdown]
# ## Q4. List all the free apps with rating more then 4.5 and category is FAMILY?

# %%
print("*"*100)
print("        These are the free apps where Category is FAMILY with rating more than 4.5.")
print("*"*100)

for i in df1:
    if(i[1] == 'FAMILY' and i[2] > 4.5 and i[6] == 'Free'):
        print(i[0])
print("-"*100)
# Out:
# ****************************************************************************************************
#         These are the free apps where Category is FAMILY with rating more than 4.5.
# ****************************************************************************************************
# Super ABC! Learning games for kids! Preschool apps
# Candy Pop Story
# Dog Run - Pet Dog Simulator
# Puzzle Kids - Animals Shapes and Jigsaw Puzzles
# No. Color - Color by Number, Number Coloring
# Garden Fruit Legend
# Piano Kids - Music & Songs
# Duolingo: Learn Languages Free
# Super ABC! Learning games for kids! Preschool apps
# Drawing for Kids Learning Games for Toddlers age 3
# Baby ABC in box! Kids alphabet games for toddlers!
# Henry Danger Crime Warp
# Fruit Cube Blast
# Toddler Kids Puzzles PUZZINGO
# Fuzzy Seasons: Animal Forest
# Dog Run - Pet Dog Simulator
# My Oasis - Calming and Relaxing Idle Clicker Game
# Ninja Dash - Ronin Jump RPG
# Monster High™ Minis Mania
# Monica Toy TV
# Sworkit Kids - Fitness Meets Fun
# Crazy Colors: Bubbles Matching
# Pino chess
# Duolingo: Learn Languages Free
# Animal Jam - Play Wild!
# Dog Sim Online: Raise a Family
# Color by Number - Draw Sandbox Pixel Art
# Build a Bridge!
# Find a Way: Addictive Puzzle
# CompTIA Exam Training
# Gymnastics Superstar - Spin your way to gold!
# Hungry Hearts Diner: A Tale of Star-Crossed Souls
# Dragon Sim Online: Be A Dragon
# Cat Sim Online: Play with Cats
# Clash of Clans
# Clash Royale
# Learn C++
# C Programming Zone
# All C Programs
# codeEazy - C/C++/JAVA
# C Functions
# Learn Basic C - For Beginners
# C Prowess
# 101 C Programming Problems
# C BOOK-C PROGRAMS
# Eternium
# Harris J Lyrics
# 2048 BTS J Hope KPop Puzzle Game
# J. Cole Albums (2007-2017)
# K-Otic Universe
# CASE K-12 Math English Science
# K-Spapp, the K-Space app
# EXO-L
# Fantastic Chefs: Match 'n Cook
# Twitch: Livestream Multiplayer Games & Esports
# Channel U
# Get Free V-bucks_fortnite Hints
# Easy V-Bux free
# X-Wing Squadron Builder
# JW Caleb y Sofia
# PewDiePie's Tuber Simulator
# Z-Empire: Dead Strike
# Angry Birds Blast
# Angry Birds Match
# Angry Birds 2
# Alchemy Classic Ad Free
# Nasihat - Chalo ae Pyaara
# 9GAG: Funny Gifs, Pics, Memes & Videos for IGTV
# Orbita AI — Exciting mobile puzzles & riddles
# Learn Artificial Intelligence
# Animal Jam - Play Wild!
# AJ Official
# Little Pets Animal Guardians
# AJ Rafael Music Lessons
# Weapon stripping 3D
# Al jazeera TV
# Al Quran Audio (Full 30 Juz)
# Quran for All (Al-Huda Int.)
# Ayat - Al Quran
# Quran Juz-30 - Mahad al Zahra
# Al Quran MP3 - Quran Reading®
# Al-Quran Ahmad Saud Offline
# Virtual lover
# virtual lover 3D
# Bubbu – My Virtual Pet
# AP® Guide
# AP Mobile
# Study AP World History
# AP Chemistry Prep: Practice Tests and Flashcards
# AP World History: Practice Tests and Flashcards
# AP Biology Prep: Practice Tests, Flashcards
# AP European History: Practice Tests and Flashcards
# Adventure Quest World Mobile Quiz
# AQ Ria Retail
# Accounting Quiz (AQ) Malaysia
# Wowkwis aq Ka'qaquj
# Questland: Turn Based RPG
# Grow Stone Online : 2d pixel RPG, MMORPG game
# Egg, Inc.
# Choices: Stories You Play
# Aw Restaurant
# AW Training
# Anime Expo 2018
# INTERACTIVE CALCULUS FOR MATHS AND PHYSICS
# Pinoy Kid Song Ako ay may Lobo
# Quran Khmer Offline AY
# Permit Test AZ Arizona MVD DOT
# Catalyst AZ
# Az Video Status
# Goody.ba
# Learn alif ba ta
# Arabic Alphabet Alif Ba Ta Wooden Blocks
# Let's Learn Alif Ba Ta
# Sufara.ba
# Elif Ba - Learn The Holy Quran
# Elifba Quran Learning Game
# Railroad Radio Vancouver BC
# BD Online Passport Application
# BD Hospital's
# Exam Result BD
# BG Future School
# Learn Bulgarian Free
# Bh Public School
# BH Challenge - Museum of the Jewish People
# Bitmoji – Your Personal Emoji
# Business Intelligence & Data
# TED
# English Grammar Test
# HON. B.J. ACS COLLEGE ALE
# BK Video Status
# Audio Murli Glossary For BK
# Baba Yaad Hai?(BK's)
# BK murli today (Mobile Murli) - Gyan
# BK Murli Dictionary (H to E)
# BkEmu - BK-0010/11M emulator
# Cerulean Heart
# あなカレ【BL】無料ゲーム
# BM SPM Practice
# Township
# Blood Pressure Diary
# RoboPad
# Br Shafi
# Companion for Fortnite & Fortnite Battle Royale
# Vlogger Go Viral - Tuber Game
# Loved by King Bs
# BS CS IT & SE
# Marked by King Bs
# COMSATS BOOK STORE FOR BS(CS)
# Beauty Rental Shop
# Sleeping Delivery
# Wifi BT Scanner
# BU Study
# Barisal University App-BU Face
# BU Students' Rep. Council
# BU Calculator
# BV Sridhara Maharaj
# Quadratic Equation Solver with Steps and Graphs
# Sandbox - Color by Number Coloring Pages
# Sandbox Art-Sandbox Color by Number Coloring Pages
# Color By Number - Sandbox Pixel Coloring Book
# PixelDot - Color by Number Sandbox Pixel Art
# PixPanda - Color by Number Pixel Art Coloring Book
# Pixyfy: coloring by number coloring book
# Draw Color by Number - Sandbox Pixel Art
# Butterfly Pixel Art - coloring by number
# Color by Number: Pixel Art
# UNICORN - Color By Number & Pixel Art Coloring
# FunnyPixels - Color by number Sandbox
# No.Diamond – Colors by Number
# Park Limousine: Realistic Limo Parking Simulator
# CB News
# CB Register
# CD CHOICE TUBE
# Yazdani Cd Center EllahAbad Official App
# MCQ CE IT
# Magana Jari ce Littafi Na Uku : Part 3 of 3
# CF Life
# All Info about Cg
# CG FM
# CG - Chemistry free
# CG Jobs
# BF CG Abstract Pictures
# CI Dictionary
# Sir C J New Primary School
# Louis CK
# Tic Tac CK
# Castle Clash: Heroes of the Empire US
# Cartoon Network Match Land
# Super Slime Blitz - Gumball
# Surely You Quest - Magiswords
# We Bare Bears Match3 Repairs
# Champions and Challengers - Adventure Time
# CN Resident
# CP Channel
# Foothills CP
# Cp Calculator for Evolution:GO
# ClanManagerTT2
# Christian Questions Podcast
# CR & CoC Private Server - Clash Barbarians PRO
# Ultimate Clash Royale Tracker
# Servidor Privado de CR y CoC - Light Royale
# Deck Shop for Clash Royale
# Cr Aviation Academy
# CS Interview Questions (TechQ)
# DU CS Lectures - Learn to Code for Free
# CS & IT Interview Questions
# CA CS Network
# CT Scan Generations
# CT Brain Interpretation
# Permit Test Connecticut CT DMV
# Cy-Reader
# MadLipz
# DB Tools
# DB for Hustle Castle
# MARVEL Future Fight
# DC N COMPANY ENTERTAINMENT RADIO!
# Driver Permit Test Prep DC DMV Driver's License Ed
# Coloring Book for Me & Mandala
# Anime Love Story Games: ✨Shadowtime✨
# DH-UFO
# Idle Heroes
# Duolingo: Learn Languages Free
# PK and DK Audio App
# dk
# Account Class-12 Solutions (D K Goel) Vol-2
# DL Hughley
# DM Buddy » Learn Digital Marketing
# Disciple Maker’s (DM) Lab
# DN Employee
# Dragon Nest M
# CritDice - Dice Roller
# Maher EL Mouaikly - Offline
# Darkness Rises
# Latest DP and Status Pro 2018
# Faceoff DP Battle App
# RPG Dragon Lapis
# DQSalmaan - A fan made App
# DS
# MegaN64 (N64 Emulator)
# DS-Students
# DT Driving Test Theory
# WPBS-DT
# Du Chinese – Mandarin Lessons
# DV ASSIST
# DV Lottery Simulator
# DV-2019 UK/British
# DW Audio
# German Listening
# Piczle Lines DX
# DX Simulation for OOO Dx Belt
# DX Simulation for Kabuto Henshin Belt 2018
# DX Simulation for Double Dx Henshin Belt 2018
# KPS CHAUHAN DY/DX
# DYPSOET
# Typical EA Game
# EC Calgary
# EC Fairgrounds
# GATE Syllabus for EC 2018 & Notifications
# English Conversation Courses
# Dance Magic Fashion Style Games
# EI国际
# TeamWard – live help for LoL
# Master E.K
# Ek Onkar
# Pyaar Ek Dhoka
# Ek Bander Ne Kholi Dukan
# Toilet Ek Prem Katha Songs Lyrics in Hindi
# Sanu Ek Pal Chain Song Videos - RAID Movie Songs
# Ek Qissa He Quran Se (Qurani Waqiyat)
# Lyrics of Ek Paheli Leela
# Exiled Kingdoms RPG
# Shabad Gurubani Punjabi mp3 free - Ek Onkar Satnam
# El Falı
# OWLIE BOO
# Narcos: Cartel Wars
# Hello English: Learn English
# Learn Top 300 English Words
# Masha and the Bear. Games for kids
# Masha and The Bear Jam Day Match 3 games for kids
# Masha and the Bear: Good Night!
# EP Radio
# Super Doctor 2 - My Newborn Baby ER Injection
# Open Heart Surgery Hospital ER: Crazy Doctor Sim
# YEBIS OpenGL ES 3.0 Tech Demo
# Advanced calculator fx 991 es plus & 991 ms plus
# Castle Clash: Epic Empire ES
# School scientific calculator fx 500 es plus 500 ms
# Lettre et demande d'emploi
# daskal.eu
# PokeType - Dex
# Pink Guy - Ey B0ss
# Ey Sey Storytime រឿងនិទានតាឥសី
# Fallout Shelter
# Story Time FD
# FD VR Music Videos - MTV Pop and Rap in 360
# Fire Emblem Heroes
# Safe Santa Fe
# POLARIS 2MFG
# Puzzles Volvo FH 16 Trucks
# Jigsaw Volvo FH 16 Trucks
# FH School
# FK Željezničar Izzy
# Permit Test FL Florida DHSMV
# FL Lottery Results
# Scratch-Off Guide for FL Lotto
# Canvas FL
# Florida Wildflowers
# How it Works: FN SCAR assault rifle
# Ninja FN Button
# Pin-fo
# Fr Ignacio Outreach
# Castle Clash: RPG War and Strategy FR
# Fr. Daoud Lamei
# Fr. Mike Schmitz Audio Teachings
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# # Analysis Using Conditions

# %% [markdown]
# ## Q1. How many free apps are there in ART_AND_DESIGN?

# %%
df = pd.DataFrame(df1, columns=['App','Category','Rating','Reviews','Size','Installs','Type','Price','Content Rating','Genres','Last Updated','Current Ver','Android Ver'])

# %%
df_pr = df[df['Category'] == 'ART_AND_DESIGN']
print(len(df_pr[df_pr['Type'] == 'Free'])) # display only the rows which have art and design
# Out:
# 61

# %% [markdown]
# # Q2. How many apps are there in ART_AND_DESIGN with rating more then 4.5?

# %%
df_pr = df[df['Category'] == 'ART_AND_DESIGN']
print(len(df_pr[df_pr['Rating'] > 4.5]))
# Out:
# 22

# %% [markdown]
# # Q3. How many apps are there in FAMILY with rating more then 4.5 and Free?

# %%
df_pr = df[df['Category'] == 'FAMILY']
df_pr = df_pr[df_pr['Rating'] > 4.5]

len(df_pr[df_pr['Type'] == 'Free'])
# Out:
# 314

# %% [markdown]
# # Q4. List all the free apps with rating more then 4.5 and category is FAMILY?

# %%
df_pr = df[df['Category'] == 'FAMILY']
df_pr = df_pr[df_pr['Rating'] > 4.5]

result = df_pr[df_pr['Type'] == 'Free'].values

for i in result:
    print(i[0])
# Out:
# Super ABC! Learning games for kids! Preschool apps
# Candy Pop Story
# Dog Run - Pet Dog Simulator
# Puzzle Kids - Animals Shapes and Jigsaw Puzzles
# No. Color - Color by Number, Number Coloring
# Garden Fruit Legend
# Piano Kids - Music & Songs
# Duolingo: Learn Languages Free
# Super ABC! Learning games for kids! Preschool apps
# Drawing for Kids Learning Games for Toddlers age 3
# Baby ABC in box! Kids alphabet games for toddlers!
# Henry Danger Crime Warp
# Fruit Cube Blast
# Toddler Kids Puzzles PUZZINGO
# Fuzzy Seasons: Animal Forest
# Dog Run - Pet Dog Simulator
# My Oasis - Calming and Relaxing Idle Clicker Game
# Ninja Dash - Ronin Jump RPG
# Monster High™ Minis Mania
# Monica Toy TV
# Sworkit Kids - Fitness Meets Fun
# Crazy Colors: Bubbles Matching
# Pino chess
# Duolingo: Learn Languages Free
# Animal Jam - Play Wild!
# Dog Sim Online: Raise a Family
# Color by Number - Draw Sandbox Pixel Art
# Build a Bridge!
# Find a Way: Addictive Puzzle
# CompTIA Exam Training
# Gymnastics Superstar - Spin your way to gold!
# Hungry Hearts Diner: A Tale of Star-Crossed Souls
# Dragon Sim Online: Be A Dragon
# Cat Sim Online: Play with Cats
# Clash of Clans
# Clash Royale
# Learn C++
# C Programming Zone
# All C Programs
# codeEazy - C/C++/JAVA
# C Functions
# Learn Basic C - For Beginners
# C Prowess
# 101 C Programming Problems
# C BOOK-C PROGRAMS
# Eternium
# Harris J Lyrics
# 2048 BTS J Hope KPop Puzzle Game
# J. Cole Albums (2007-2017)
# K-Otic Universe
# CASE K-12 Math English Science
# K-Spapp, the K-Space app
# EXO-L
# Fantastic Chefs: Match 'n Cook
# Twitch: Livestream Multiplayer Games & Esports
# Channel U
# Get Free V-bucks_fortnite Hints
# Easy V-Bux free
# X-Wing Squadron Builder
# JW Caleb y Sofia
# PewDiePie's Tuber Simulator
# Z-Empire: Dead Strike
# Angry Birds Blast
# Angry Birds Match
# Angry Birds 2
# Alchemy Classic Ad Free
# Nasihat - Chalo ae Pyaara
# 9GAG: Funny Gifs, Pics, Memes & Videos for IGTV
# Orbita AI — Exciting mobile puzzles & riddles
# Learn Artificial Intelligence
# Animal Jam - Play Wild!
# AJ Official
# Little Pets Animal Guardians
# AJ Rafael Music Lessons
# Weapon stripping 3D
# Al jazeera TV
# Al Quran Audio (Full 30 Juz)
# Quran for All (Al-Huda Int.)
# Ayat - Al Quran
# Quran Juz-30 - Mahad al Zahra
# Al Quran MP3 - Quran Reading®
# Al-Quran Ahmad Saud Offline
# Virtual lover
# virtual lover 3D
# Bubbu – My Virtual Pet
# AP® Guide
# AP Mobile
# Study AP World History
# AP Chemistry Prep: Practice Tests and Flashcards
# AP World History: Practice Tests and Flashcards
# AP Biology Prep: Practice Tests, Flashcards
# AP European History: Practice Tests and Flashcards
# Adventure Quest World Mobile Quiz
# AQ Ria Retail
# Accounting Quiz (AQ) Malaysia
# Wowkwis aq Ka'qaquj
# Questland: Turn Based RPG
# Grow Stone Online : 2d pixel RPG, MMORPG game
# Egg, Inc.
# Choices: Stories You Play
# Aw Restaurant
# AW Training
# Anime Expo 2018
# INTERACTIVE CALCULUS FOR MATHS AND PHYSICS
# Pinoy Kid Song Ako ay may Lobo
# Quran Khmer Offline AY
# Permit Test AZ Arizona MVD DOT
# Catalyst AZ
# Az Video Status
# Goody.ba
# Learn alif ba ta
# Arabic Alphabet Alif Ba Ta Wooden Blocks
# Let's Learn Alif Ba Ta
# Sufara.ba
# Elif Ba - Learn The Holy Quran
# Elifba Quran Learning Game
# Railroad Radio Vancouver BC
# BD Online Passport Application
# BD Hospital's
# Exam Result BD
# BG Future School
# Learn Bulgarian Free
# Bh Public School
# BH Challenge - Museum of the Jewish People
# Bitmoji – Your Personal Emoji
# Business Intelligence & Data
# TED
# English Grammar Test
# HON. B.J. ACS COLLEGE ALE
# BK Video Status
# Audio Murli Glossary For BK
# Baba Yaad Hai?(BK's)
# BK murli today (Mobile Murli) - Gyan
# BK Murli Dictionary (H to E)
# BkEmu - BK-0010/11M emulator
# Cerulean Heart
# あなカレ【BL】無料ゲーム
# BM SPM Practice
# Township
# Blood Pressure Diary
# RoboPad
# Br Shafi
# Companion for Fortnite & Fortnite Battle Royale
# Vlogger Go Viral - Tuber Game
# Loved by King Bs
# BS CS IT & SE
# Marked by King Bs
# COMSATS BOOK STORE FOR BS(CS)
# Beauty Rental Shop
# Sleeping Delivery
# Wifi BT Scanner
# BU Study
# Barisal University App-BU Face
# BU Students' Rep. Council
# BU Calculator
# BV Sridhara Maharaj
# Quadratic Equation Solver with Steps and Graphs
# Sandbox - Color by Number Coloring Pages
# Sandbox Art-Sandbox Color by Number Coloring Pages
# Color By Number - Sandbox Pixel Coloring Book
# PixelDot - Color by Number Sandbox Pixel Art
# PixPanda - Color by Number Pixel Art Coloring Book
# Pixyfy: coloring by number coloring book
# Draw Color by Number - Sandbox Pixel Art
# Butterfly Pixel Art - coloring by number
# Color by Number: Pixel Art
# UNICORN - Color By Number & Pixel Art Coloring
# FunnyPixels - Color by number Sandbox
# No.Diamond – Colors by Number
# Park Limousine: Realistic Limo Parking Simulator
# CB News
# CB Register
# CD CHOICE TUBE
# Yazdani Cd Center EllahAbad Official App
# MCQ CE IT
# Magana Jari ce Littafi Na Uku : Part 3 of 3
# CF Life
# All Info about Cg
# CG FM
# CG - Chemistry free
# CG Jobs
# BF CG Abstract Pictures
# CI Dictionary
# Sir C J New Primary School
# Louis CK
# Tic Tac CK
# Castle Clash: Heroes of the Empire US
# Cartoon Network Match Land
# Super Slime Blitz - Gumball
# Surely You Quest - Magiswords
# We Bare Bears Match3 Repairs
# Champions and Challengers - Adventure Time
# CN Resident
# CP Channel
# Foothills CP
# Cp Calculator for Evolution:GO
# ClanManagerTT2
# Christian Questions Podcast
# CR & CoC Private Server - Clash Barbarians PRO
# Ultimate Clash Royale Tracker
# Servidor Privado de CR y CoC - Light Royale
# Deck Shop for Clash Royale
# Cr Aviation Academy
# CS Interview Questions (TechQ)
# DU CS Lectures - Learn to Code for Free
# CS & IT Interview Questions
# CA CS Network
# CT Scan Generations
# CT Brain Interpretation
# Permit Test Connecticut CT DMV
# Cy-Reader
# MadLipz
# DB Tools
# DB for Hustle Castle
# MARVEL Future Fight
# DC N COMPANY ENTERTAINMENT RADIO!
# Driver Permit Test Prep DC DMV Driver's License Ed
# Coloring Book for Me & Mandala
# Anime Love Story Games: ✨Shadowtime✨
# DH-UFO
# Idle Heroes
# Duolingo: Learn Languages Free
# PK and DK Audio App
# dk
# Account Class-12 Solutions (D K Goel) Vol-2
# DL Hughley
# DM Buddy » Learn Digital Marketing
# Disciple Maker’s (DM) Lab
# DN Employee
# Dragon Nest M
# CritDice - Dice Roller
# Maher EL Mouaikly - Offline
# Darkness Rises
# Latest DP and Status Pro 2018
# Faceoff DP Battle App
# RPG Dragon Lapis
# DQSalmaan - A fan made App
# DS
# MegaN64 (N64 Emulator)
# DS-Students
# DT Driving Test Theory
# WPBS-DT
# Du Chinese – Mandarin Lessons
# DV ASSIST
# DV Lottery Simulator
# DV-2019 UK/British
# DW Audio
# German Listening
# Piczle Lines DX
# DX Simulation for OOO Dx Belt
# DX Simulation for Kabuto Henshin Belt 2018
# DX Simulation for Double Dx Henshin Belt 2018
# KPS CHAUHAN DY/DX
# DYPSOET
# Typical EA Game
# EC Calgary
# EC Fairgrounds
# GATE Syllabus for EC 2018 & Notifications
# English Conversation Courses
# Dance Magic Fashion Style Games
# EI国际
# TeamWard – live help for LoL
# Master E.K
# Ek Onkar
# Pyaar Ek Dhoka
# Ek Bander Ne Kholi Dukan
# Toilet Ek Prem Katha Songs Lyrics in Hindi
# Sanu Ek Pal Chain Song Videos - RAID Movie Songs
# Ek Qissa He Quran Se (Qurani Waqiyat)
# Lyrics of Ek Paheli Leela
# Exiled Kingdoms RPG
# Shabad Gurubani Punjabi mp3 free - Ek Onkar Satnam
# El Falı
# OWLIE BOO
# Narcos: Cartel Wars
# Hello English: Learn English
# Learn Top 300 English Words
# Masha and the Bear. Games for kids
# Masha and The Bear Jam Day Match 3 games for kids
# Masha and the Bear: Good Night!
# EP Radio
# Super Doctor 2 - My Newborn Baby ER Injection
# Open Heart Surgery Hospital ER: Crazy Doctor Sim
# YEBIS OpenGL ES 3.0 Tech Demo
# Advanced calculator fx 991 es plus & 991 ms plus
# Castle Clash: Epic Empire ES
# School scientific calculator fx 500 es plus 500 ms
# Lettre et demande d'emploi
# daskal.eu
# PokeType - Dex
# Pink Guy - Ey B0ss
# Ey Sey Storytime រឿងនិទានតាឥសី
# Fallout Shelter
# Story Time FD
# FD VR Music Videos - MTV Pop and Rap in 360
# Fire Emblem Heroes
# Safe Santa Fe
# POLARIS 2MFG
# Puzzles Volvo FH 16 Trucks
# Jigsaw Volvo FH 16 Trucks
# FH School
# FK Željezničar Izzy
# Permit Test FL Florida DHSMV
# FL Lottery Results
# Scratch-Off Guide for FL Lotto
# Canvas FL
# Florida Wildflowers
# How it Works: FN SCAR assault rifle
# Ninja FN Button
# Pin-fo
# Fr Ignacio Outreach
# Castle Clash: RPG War and Strategy FR
# Fr. Daoud Lamei
# Fr. Mike Schmitz Audio Teachings

# %% [markdown]
# # GroupBy in Pandas

# %% [markdown]
# ### Q1. Name the apps that are in ART_AND_DESIGN with rating more then 4.5 in descending order WRT Ratings?

# %%
df_pr = df[df['Category'] == 'ART_AND_DESIGN']
df_pr = df_pr[df_pr['Rating'] > 4.5]

df_pr.sort_values( by = 'Rating', ascending = True )Q2. Which category is having maximum average rating Descending order?
# Out:
#                                                     App        Category  \
# 13                                Mandala Coloring Book  ART_AND_DESIGN
# 18                                         ibis Paint X  ART_AND_DESIGN
# 45    Install images with music to make video withou...  ART_AND_DESIGN
# 2     U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN
# 4760     X Launcher Prime: With OS Style Theme & No Ads  ART_AND_DESIGN
# 4751  X Launcher Pro: PhoneX Theme, OS11 Control Center  ART_AND_DESIGN
# 4745  X Launcher: With OS11 Style Theme & Control Ce...  ART_AND_DESIGN
# 44    Canva: Poster, banner, card maker & graphic de...  ART_AND_DESIGN
# 37                       PIP Camera - PIP Collage Maker  ART_AND_DESIGN
# 35       UNICORN - Color By Number & Pixel Art Coloring  ART_AND_DESIGN
# 25                        Colorfit - Drawing & Coloring  ART_AND_DESIGN
# 23                          HD Mickey Minnie Wallpapers  ART_AND_DESIGN
# 21              Superheroes Wallpapers | 4K Backgrounds  ART_AND_DESIGN
# 15         Photo Designer - Write your name with shapes  ART_AND_DESIGN
# 9                         Kids Paint Free - Drawing Fun  ART_AND_DESIGN
# 33                                      I Creative Idea  ART_AND_DESIGN
# 6924               Fantasy theme dark bw black building  ART_AND_DESIGN
# 24                           Harley Quinn wallpapers HD  ART_AND_DESIGN
# 3980                                  Cardi B Wallpaper  ART_AND_DESIGN
# 4755  X Launcher Pro - IOS Style Theme & Control Center  ART_AND_DESIGN
# 5250                            AJ Styles HD Wallpapers  ART_AND_DESIGN
# 8879            Spring flowers theme couleurs d t space  ART_AND_DESIGN
#
#      Rating Reviews  Size     Installs  Type  Price Content Rating  \
# 13      4.6    4326   21M     100,000+  Free      0       Everyone
# 18      4.6  224399   31M  10,000,000+  Free      0       Everyone
# 45      4.6    1070   26M     100,000+  Free      0       Everyone
# 2       4.7   87510  8.7M   5,000,000+  Free      0       Everyone
# 4760    4.7     149  3.5M       1,000+  Paid  $1.99       Everyone
# 4751    4.7     801  3.5M       5,000+  Paid  $1.99       Everyone
# 4745    4.7    5754  4.4M     100,000+  Free      0       Everyone
# 44      4.7  174531   24M  10,000,000+  Free      0       Everyone
# 37      4.7     158   11M      10,000+  Free      0       Everyone
# 35      4.7    8145   24M     500,000+  Free      0       Everyone
# 25      4.7   20260   25M     500,000+  Free      0       Everyone
# 23      4.7     118   23M      50,000+  Free      0       Everyone
# 21      4.7    7699  4.2M     500,000+  Free      0   Everyone 10+
# 15      4.7    3632  5.5M     500,000+  Free      0       Everyone
# 9       4.7     121  3.1M      10,000+  Free      0       Everyone
# 33      4.7     353  4.2M      10,000+  Free      0           Teen
# 6924    4.8      41  1.9M       5,000+  Free      0       Everyone
# 24      4.8     192  6.0M      10,000+  Free      0       Everyone
# 3980    4.8     253  3.7M      50,000+  Free      0       Everyone
# 4755    4.8    1216  8.6M      10,000+  Paid  $1.99       Everyone
# 5250    4.8      48   25M       5,000+  Free      0       Everyone
# 8879    5.0       1  2.9M         100+  Free      0       Everyone
#
#                        Genres       Last Updated Current Ver   Android Ver
# 13               Art & Design      June 26, 2018       1.0.4    4.4 and up
# 18               Art & Design      July 30, 2018       5.5.4    4.1 and up
# 45               Art & Design  November 14, 2017         1.6    4.1 and up
# 2                Art & Design     August 1, 2018       1.2.4  4.0.3 and up
# 4760             Art & Design      July 30, 2018       1.2.2    4.1 and up
# 4751             Art & Design      July 30, 2018       2.1.2    4.1 and up
# 4745             Art & Design      July 30, 2018       2.1.2    4.1 and up
# 44               Art & Design      July 31, 2018       1.6.1    4.1 and up
# 37               Art & Design  November 29, 2017         1.3  4.0.3 and up
# 35    Art & Design;Creativity     August 2, 2018       1.0.9    4.4 and up
# 25    Art & Design;Creativity   October 11, 2017       1.0.8  4.0.3 and up
# 23               Art & Design       July 7, 2018       1.1.3    4.1 and up
# 21               Art & Design      July 12, 2018     2.2.6.2  4.0.3 and up
# 15               Art & Design      July 31, 2018         3.1    4.1 and up
# 9     Art & Design;Creativity       July 3, 2018         2.8  4.0.3 and up
# 33               Art & Design     April 27, 2018         1.6    4.1 and up
# 6924             Art & Design     March 20, 2018       1.0.2    4.0 and up
# 24               Art & Design     April 25, 2018         1.5    3.0 and up
# 3980             Art & Design   November 1, 2017       1.0.0    4.0 and up
# 4755             Art & Design      June 26, 2018       1.0.0    4.1 and up
# 5250             Art & Design     August 4, 2018       1.1.1    4.1 and up
# 8879             Art & Design     April 18, 2018       1.0.2    4.0 and up

# %% [markdown]
# ### Q2. Which category is having maximum average rating Descending order?

# %%
# df['Rating'] = pd.to_numeric(df['Rating'] , errors='coerce') # converted Reting column from string to numeric
# df_clean = df.dropna(subset = ['Rating']) # dropped the NaN values 
# result = df_clean.groupby('Category')['Rating'].mean().sort_values(ascending = False)

# No of apps in each category
result = df_clean.groupby('Category')['Type'].count().sort_values(ascending = False)

# %%
result
# Out:
# Category
# FAMILY                 1968
# GAME                   1144
# TOOLS                   841
# MEDICAL                 463
# BUSINESS                460
# PRODUCTIVITY            424
# PERSONALIZATION         390
# COMMUNICATION           387
# SPORTS                  384
# LIFESTYLE               382
# FINANCE                 366
# HEALTH_AND_FITNESS      341
# PHOTOGRAPHY             335
# SOCIAL                  295
# NEWS_AND_MAGAZINES      283
# SHOPPING                260
# TRAVEL_AND_LOCAL        258
# DATING                  234
# BOOKS_AND_REFERENCE     230
# VIDEO_PLAYERS           175
# EDUCATION               156
# ENTERTAINMENT           149
# MAPS_AND_NAVIGATION     137
# FOOD_AND_DRINK          127
# HOUSE_AND_HOME           88
# AUTO_AND_VEHICLES        85
# LIBRARIES_AND_DEMO       84
# WEATHER                  82
# EVENTS                   64
# ART_AND_DESIGN           64
# PARENTING                60
# COMICS                   60
# BEAUTY                   53
# Name: Type, dtype: int64

# %% [markdown]
# ## Q3. How many paid apps are there in each category in Descending Order?

# %%
df_pr = df[df['Type'] == 'Paid']

df_pr.groupby('Category').count()['Type'].sort_values(ascending = False)
# Out:
# Category
# FAMILY                 190
# MEDICAL                109
# GAME                    83
# PERSONALIZATION         82
# TOOLS                   77
# BOOKS_AND_REFERENCE     28
# PRODUCTIVITY            28
# COMMUNICATION           27
# SPORTS                  24
# PHOTOGRAPHY             22
# LIFESTYLE               19
# FINANCE                 17
# HEALTH_AND_FITNESS      16
# BUSINESS                14
# TRAVEL_AND_LOCAL        12
# WEATHER                  8
# DATING                   7
# MAPS_AND_NAVIGATION      5
# EDUCATION                4
# VIDEO_PLAYERS            4
# AUTO_AND_VEHICLES        3
# SOCIAL                   3
# ART_AND_DESIGN           3
# NEWS_AND_MAGAZINES       2
# PARENTING                2
# FOOD_AND_DRINK           2
# SHOPPING                 2
# ENTERTAINMENT            2
# LIBRARIES_AND_DEMO       1
# EVENTS                   1
# Name: Type, dtype: int64
